# %%
import pandas as pd
from pathlib import Path

# ---------- CONFIG ----------
DB_FOLDER_NAME = "MarathiWN_1_3/database"
DATA_FILE = 'data_txt'
POS_MAP = {'01':'noun', '02':'adjective', '03':'verb', '04':'adverb'}

# ---------- LOCATE DATABASE ----------
cwd = Path.cwd()
db_folder = cwd / DB_FOLDER_NAME
data_path = db_folder / DATA_FILE
if not data_path.exists():
    raise FileNotFoundError(f"Database file not found: {data_path}")
print(f"Found MarathiWN data file at: {data_path}")

# ---------- PARSE DATA.TXT ----------
records = []

with open(data_path, 'r', encoding='utf-8', errors='ignore') as f:
    for line in f:
        line = line.strip()
        if not line or line.startswith('#') or '|' not in line:
            continue
        left, gloss = line.split('|', maxsplit=1)
        left_parts = left.split()
        if len(left_parts) < 3:
            continue
        pos_code = left_parts[1]  # 2nd column = POS code
        pos_name = POS_MAP.get(pos_code, 'unknown')
        # 4th column onwards is the Marathi word(s)
        word_field = left_parts[3]
        # words can be ':' separated
        words = word_field.split(':')
        # synset ID is always the last numeric field
        synset_id = next((p for p in reversed(left_parts) if p.isdigit()), '')
        for w in words:
            records.append({
                'marathi_word': w,
                'pos': pos_name,
                'synset_id': synset_id,
                'gloss': gloss.strip()
            })

df = pd.DataFrame(records)
out_csv = Path.cwd() / 'marathi_lexicon_correct_pos.csv'
df.to_csv(out_csv, index=False, encoding='utf-8')
print(f"Saved CSV with correct POS and glosses: {out_csv}")
print(df.head(20))
# Out:
# Found MarathiWN data file at: c:\LLM's_for_SA\MarathiWN_1_3\database\data_txt
# Saved CSV with correct POS and glosses: c:\LLM's_for_SA\marathi_lexicon_correct_pos.csv
#      marathi_word        pos synset_id  \
# 0          अजन्मा  adjective  00000101
# 1            अशुभ  adjective  00000101
# 2           अमंगळ  adjective  00000101
# 3       अप्रविष्ट  adjective  00000111
# 4       पुण्यभूमी    unknown  00000037
# 5      पवित्रभूमी    unknown  00000037
# 6      पुण्यस्थान    unknown  00000037
# 7     पवित्रस्थान    unknown  00000037
# 8       पावनस्थान    unknown  00000037
# 9          शिवालय       noun  00000037
# 10       शिवमंदिर       noun  00000037
# 11  अपवित्र_स्थान       noun  00000037
# 12          आलेला  adjective  00000101
# 13            आगत  adjective  00000101
# 14       जन्मलेला  adjective  00000101
# 15        जलमलेला  adjective  00000101
# 16       जल्मलेला  adjective  00000101
# 17        सत्कर्म       noun  00000058
# 18          सुकृत       noun  00000058
# 19    नैतिक_कार्य       noun  00000058
#
#                                                 gloss
# 0              ज्यास जन्म नाही असा:"ईश्वर अजन्मा आहे"
# 1   शुभ नाही असा:"या योगामूळे कुंडलीतील इतर अशुभ य...
# 2   शुभ नाही असा:"या योगामूळे कुंडलीतील इतर अशुभ य...
# 3   ज्याने प्रवेश केला नाही असा:"अप्रविष्ट व्यक्ती...
# 4   पवित्र मानले गेलेले स्थान:"हिंदूंसाठी काशी ही ...
# 5   पवित्र मानले गेलेले स्थान:"हिंदूंसाठी काशी ही ...
# 6   पवित्र मानले गेलेले स्थान:"हिंदूंसाठी काशी ही ...
# 7   पवित्र मानले गेलेले स्थान:"हिंदूंसाठी काशी ही ...
# 8   पवित्र मानले गेलेले स्थान:"हिंदूंसाठी काशी ही ...
# 9   जिथे शंकराच्या पिंडीची स्थापना केली असून त्याच...
# 10  जिथे शंकराच्या पिंडीची स्थापना केली असून त्याच...
# 11  असे स्थान जे पवित्र मानले जात नाही:"धार्मिक वि...
# 12      दाखल झालेला:"आलेल्या पाहुण्यांचे स्वागत आहे."
# 13      दाखल झालेला:"आलेल्या पाहुण्यांचे स्वागत आहे."
# 14  ज्याने जन्म घेतला आहे असा:"जन्मलेल्या प्राणीचा...
# 15  ज्याने जन्म घेतला आहे असा:"जन्मलेल्या प्राणीचा...
# 16  ज्याने जन्म घेतला आहे असा:"जन्मलेल्या प्राणीचा...
# 17  असे कार्य जे नीतिला धरून केलेले असते आणि ज्यात...
# 18  असे कार्य जे नीतिला धरून केलेले असते आणि ज्यात...
# 19  असे कार्य जे नीतिला धरून केलेले असते आणि ज्यात...

# %%
df[50:100]
# Out:
#     marathi_word        pos synset_id  \
# 50   खाद्यपदार्थ       noun  00000029
# 51  खाद्य_पदार्थ       noun  00000029
# 52    खाद्यवस्तू       noun  00000029
# 53   खाद्य_वस्तू       noun  00000029
# 54    अन्नपदार्थ       noun  00000029
# 55       अननुभवी  adjective  00000101
# 56          नवखा  adjective  00000101
# 57           नवा  adjective  00000101
# 58         कच्चा  adjective  00000101
# 59         अकुशल  adjective  00000101
# 60        अयोग्य  adjective  00000101
# 61        नालायक  adjective  00000101
# 62    अकार्यक्षम  adjective  00000101
# 63         वाघीण       noun  00000011
# 64         वेउळी       noun  00000011
# 65        नवशिका  adjective  00000101
# 66          नवखा  adjective  00000101
# 67           नवा  adjective  00000101
# 68          नवीन  adjective  00000101
# 69    अव्यवस्थित  adjective  00000101
# 70         अजागळ  adjective  00000101
# 71         गबाळा  adjective  00000101
# 72         मूर्ख  adjective  00000101
# 73         बावळा  adjective  00000101
# 74         बावळट  adjective  00000101
# 75       अज्ञानी  adjective  00000101
# 76           मूढ  adjective  00000101
# 77            जड  adjective  00000101
# 78           मंद  adjective  00000101
# 79     निर्बुद्ध  adjective  00000101
# 80          मठ्ठ  adjective  00000101
# 81       बेअक्कल  adjective  00000101
# 82           शंख  adjective  00000101
# 83        बिनडोक  adjective  00000101
# 84         अडाणी  adjective  00000101
# 85             ढ  adjective  00000101
# 86       ठोंब्या  adjective  00000101
# 87        अर्धवट  adjective  00000101
# 88      बेअक्कली  adjective  00000101
# 89           भोट  adjective  00000101
# 90         खेंदड  adjective  00000101
# 91        खेंदाड  adjective  00000101
# 92      अप्रचलित  adjective  00000101
# 93  चलनात_नसलेला  adjective  00000101
# 94        प्रवीण  adjective  00000101
# 95         निपुण  adjective  00000101
# 96         हुशार  adjective  00000101
# 97          कुशल  adjective  00000101
# 98         जाणता  adjective  00000101
# 99        पारंगत  adjective  00000101
#
#                                                 gloss
# 50  खाण्याजोगी वस्तू:"दूध आणि दुधाचे इतर पदार्थ उद...
# 51  खाण्याजोगी वस्तू:"दूध आणि दुधाचे इतर पदार्थ उद...
# 52  खाण्याजोगी वस्तू:"दूध आणि दुधाचे इतर पदार्थ उद...
# 53  खाण्याजोगी वस्तू:"दूध आणि दुधाचे इतर पदार्थ उद...
# 54  खाण्याजोगी वस्तू:"दूध आणि दुधाचे इतर पदार्थ उद...
# 55     अनुभव नसलेला:"तो ह्या बाबतीत अजून अननुभवी आहे"
# 56     अनुभव नसलेला:"तो ह्या बाबतीत अजून अननुभवी आहे"
# 57     अनुभव नसलेला:"तो ह्या बाबतीत अजून अननुभवी आहे"
# 58     अनुभव नसलेला:"तो ह्या बाबतीत अजून अननुभवी आहे"
# 59  कुशल नसलेला:"अकुशल व अर्धकुशल कामगार कनिष्ठ स्...
# 60  योग्य नसणारा:"पंतप्रधानांनी अयोग्य मंत्र्यांना...
# 61  योग्य नसणारा:"पंतप्रधानांनी अयोग्य मंत्र्यांना...
# 62  योग्य नसणारा:"पंतप्रधानांनी अयोग्य मंत्र्यांना...
# 63    वाघाची मादी:"वाघीण आपल्या पिल्लांसह हिंडत होती"
# 64    वाघाची मादी:"वाघीण आपल्या पिल्लांसह हिंडत होती"
# 65  नुकताच एखादे काम करायला शिकलेला:"हे काम कुणाही...
# 66  नुकताच एखादे काम करायला शिकलेला:"हे काम कुणाही...
# 67  नुकताच एखादे काम करायला शिकलेला:"हे काम कुणाही...
# 68  नुकताच एखादे काम करायला शिकलेला:"हे काम कुणाही...
# 69  नीटनेटके काम न करणारा:"तू अव्यवस्थित माणसांसार...
# 70  नीटनेटके काम न करणारा:"तू अव्यवस्थित माणसांसार...
# 71  नीटनेटके काम न करणारा:"तू अव्यवस्थित माणसांसार...
# 72  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 73  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 74  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 75  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 76  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 77  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 78  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 79  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 80  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 81  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 82  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 83  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 84  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 85  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 86  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 87  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 88  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 89  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 90  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 91  ज्याला बुद्धी नाही किंवा कमी आहे असा:"मूर्ख मा...
# 92  चलनात नसलेला:"त्यांनी या लेखात बरेच अप्रचलित श...
# 93  चलनात नसलेला:"त्यांनी या लेखात बरेच अप्रचलित श...
# 94  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...
# 95  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...
# 96  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...
# 97  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...
# 98  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...
# 99  खास ज्ञान किंवा कौशल्य असणारा:"अर्जुन धनुर्विद...

# %%
df[df['marathi_word']=='अंगहीन']
# Out:
#      marathi_word   pos                                              gloss
# 5028       अंगहीन  verb  एखादा अवयव नसलेला:"अपघातात पाय तुटल्याने तो अप...

# %%
df.groupby('marathi_word')['pos'].unique().head(20)
# Out:
# marathi_word
# -आत                                   [adverb]
# -गत                                [adjective]
# -ग्रस्त                            [adjective]
# -च्या_वाट्याला_जाणे                     [verb]
# -च्या_वाट्याला_येणे                     [verb]
# -च्याकडे_जाणे                           [verb]
# -ज                                 [adjective]
# -जन्य                              [adjective]
# -तरंग                                   [noun]
# -धारा                                   [noun]
# -निर्मित                           [adjective]
# -मान्य                             [adjective]
# -वर                                   [adverb]
# -वरती                                 [adverb]
# -सारखा                                  [noun]
# 0000                                    [noun]
# 0001                   [noun, verb, adjective]
# 1000000                      [adjective, noun]
# 10000000                                [noun]
# 100000000                    [noun, adjective]
# Name: pos, dtype: object
