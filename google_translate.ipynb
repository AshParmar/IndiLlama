# %%
import pandas as pd
from pathlib import Path
from googletrans import Translator
import time
import asyncio
import nest_asyncio
from tqdm.auto import tqdm

# Apply nest_asyncio to allow asyncio.run in Jupyter
nest_asyncio.apply()

# ---------- CONFIG ----------
lexicon_csv = Path.cwd() / 'marathi_lexicon_correct_pos.csv'  # Fixed the correct file name
output_csv = Path.cwd() / 'marathi_sentiwordnet_google.csv'
batch_size = 100  # small batch to avoid API limits
start_from_batch = 0# Start from batch  (resuming from previous run)

# ---------- LOAD LEXICON ----------
df = pd.read_csv(lexicon_csv)
print(f"Loaded {len(df)} Marathi words")

# ---------- LOAD EXISTING TRANSLATIONS ----------
# If output file exists, load it to preserve existing translations
if output_csv.exists():
    saved_df = pd.read_csv(output_csv)
    if 'english_word' in saved_df.columns:
        english_words = saved_df['english_word'].tolist()
        print(f"Loaded {len(english_words)} existing translations")
    else:
        english_words = [''] * len(df)
else:
    english_words = [''] * len(df)

# Ensure english_words has the correct length
if len(english_words) < len(df):
    english_words.extend([''] * (len(df) - len(english_words)))

# ---------- TRANSLATE ----------
translator = Translator()

# Fix: Use a non-async translate function that wraps the async translator
def translate_word(word, src='mr', dest='en'):
    try:
        # Create a new translator instance for each word to avoid issues
        t = Translator().translate(word, src=src, dest=dest)
        return t.text.lower()
    except Exception as e:
        print(f"Error translating '{word}': {e}")
        return word  # fallback to original word

# Process batches
def translate_all():
    total_batches = (len(df) - 1) // batch_size + 1
    start_index = start_from_batch * batch_size
    
    print(f"Starting from batch {start_from_batch} (index {start_index}) out of {total_batches} total batches")
    
    for start in range(start_index, len(df), batch_size):
        end = min(start + batch_size, len(df))
        batch = df['marathi_word'].iloc[start:end].astype(str).tolist()
        batch_num = start // batch_size + 1
        
        print(f"Processing batch {batch_num} / {total_batches} (indices {start} to {end-1})")
        
        # Process words one by one (to maintain order and handle errors individually)
        for i, word in enumerate(batch):
            english_words[start + i] = translate_word(word)
            time.sleep(0.1)  # delay to avoid throttling
        
        # Save progress after each batch
        df_temp = df.copy()
        df_temp['english_word'] = english_words
        df_temp.to_csv(output_csv, index=False, encoding='utf-8')
        
        print(f"Completed batch {batch_num} / {total_batches}")

# Run the function (no asyncio needed now)
translate_all()

# Final save
df['english_word'] = english_words
df.to_csv(output_csv, index=False, encoding='utf-8')
print(f"✅ Saved translations to: {output_csv}")
# Out:
# Loaded 52325 Marathi words
# Loaded 42998 existing translations
# Starting from batch 430 (index 43000) out of 524 total batches
# Processing batch 431 / 524 (indices 43000 to 43099)
# Completed batch 431 / 524
# Processing batch 432 / 524 (indices 43100 to 43199)
# Completed batch 432 / 524
# Processing batch 433 / 524 (indices 43200 to 43299)
# Error translating 'जेस्सोर': The read operation timed out
# Completed batch 433 / 524
# Processing batch 434 / 524 (indices 43300 to 43399)
# Completed batch 434 / 524
# Processing batch 435 / 524 (indices 43400 to 43499)
# Error translating 'जरतार': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 435 / 524
# Processing batch 436 / 524 (indices 43500 to 43599)
# Error translating 'अरण्यसेवन': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 436 / 524
# Processing batch 437 / 524 (indices 43600 to 43699)
# Error translating 'सुवर्णरेतस': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Error translating 'विद्युत्प्रभ': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Error translating 'कडी': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Completed batch 437 / 524
# Processing batch 438 / 524 (indices 43700 to 43799)
# Error translating 'उपभाग': The read operation timed out
# Error translating 'बलाहक': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Completed batch 438 / 524
# Processing batch 439 / 524 (indices 43800 to 43899)
# Completed batch 439 / 524
# Processing batch 440 / 524 (indices 43900 to 43999)
# Error translating 'नाव_ठेवणे': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Completed batch 440 / 524
# Processing batch 441 / 524 (indices 44000 to 44099)
# Error translating 'जय': The read operation timed out
# Error translating 'शत्रुंजय_पर्वत': The read operation timed out
# Completed batch 441 / 524
# Processing batch 442 / 524 (indices 44100 to 44199)
# Completed batch 442 / 524
# Processing batch 443 / 524 (indices 44200 to 44299)
# Completed batch 443 / 524
# Processing batch 444 / 524 (indices 44300 to 44399)
# Error translating 'कांपिल्य': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 444 / 524
# Processing batch 445 / 524 (indices 44400 to 44499)
# Completed batch 445 / 524
# Processing batch 446 / 524 (indices 44500 to 44599)
# Completed batch 446 / 524
# Processing batch 447 / 524 (indices 44600 to 44699)
# Error translating 'घृणा_करणे': The read operation timed out
# Completed batch 447 / 524
# Processing batch 448 / 524 (indices 44700 to 44799)
# Completed batch 448 / 524
# Processing batch 449 / 524 (indices 44800 to 44899)
# Completed batch 449 / 524
# Processing batch 450 / 524 (indices 44900 to 44999)
# Error translating 'थ': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 450 / 524
# Processing batch 451 / 524 (indices 45000 to 45099)
# Error translating 'शमीक_ऋषी': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 451 / 524
# Processing batch 452 / 524 (indices 45100 to 45199)
# Completed batch 452 / 524
# Processing batch 453 / 524 (indices 45200 to 45299)
# Completed batch 453 / 524
# Processing batch 454 / 524 (indices 45300 to 45399)
# Error translating 'चमकवणे': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 454 / 524
# Processing batch 455 / 524 (indices 45400 to 45499)
# Completed batch 455 / 524
# Processing batch 456 / 524 (indices 45500 to 45599)
# Error translating 'जगन्नाथ': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 456 / 524
# Processing batch 457 / 524 (indices 45600 to 45699)
# Error translating 'गुपचुप': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2590)
# Completed batch 457 / 524
# Processing batch 458 / 524 (indices 45700 to 45799)
# Completed batch 458 / 524
# Processing batch 459 / 524 (indices 45800 to 45899)
# Error translating 'विरोधी': The read operation timed out
# Completed batch 459 / 524
# Processing batch 460 / 524 (indices 45900 to 45999)
# Error translating 'संपर्क_तुटणे': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Error translating 'असुरक्षित': the JSON object must be str, bytes or bytearray, not NoneType
# Error translating 'हॅक_करणे': the JSON object must be str, bytes or bytearray, not NoneType
# Completed batch 460 / 524
# Processing batch 461 / 524 (indices 46000 to 46099)
# Completed batch 461 / 524
# Processing batch 462 / 524 (indices 46100 to 46199)
# Error translating 'पुरुषार्थ': The read operation timed out
# Completed batch 462 / 524
# Processing batch 463 / 524 (indices 46200 to 46299)
# Error translating 'लष्करी_अधिकारी': The read operation timed out
# Error translating 'क्रस्ट_प्लेट': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 463 / 524
# Processing batch 464 / 524 (indices 46300 to 46399)
# Error translating 'रातांबेल': The read operation timed out
# Completed batch 464 / 524
# Processing batch 465 / 524 (indices 46400 to 46499)
# Error translating 'हार्ट_अटॅक': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 465 / 524
# Processing batch 466 / 524 (indices 46500 to 46599)
# Error translating 'माहितीचा_अधिकार': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 466 / 524
# Processing batch 467 / 524 (indices 46600 to 46699)
# Completed batch 467 / 524
# Processing batch 468 / 524 (indices 46700 to 46799)
# Completed batch 468 / 524
# Processing batch 469 / 524 (indices 46800 to 46899)
# Completed batch 469 / 524
# Processing batch 470 / 524 (indices 46900 to 46999)
# Completed batch 470 / 524
# Processing batch 471 / 524 (indices 47000 to 47099)
# Error translating 'सारथ्य': The read operation timed out
# Error translating 'डिमॅट_अकाऊंट': The read operation timed out
# Completed batch 471 / 524
# Processing batch 472 / 524 (indices 47100 to 47199)
# Error translating 'नुकसानभरपाईची_मागणी': The read operation timed out
# Completed batch 472 / 524
# Processing batch 473 / 524 (indices 47200 to 47299)
# Completed batch 473 / 524
# Processing batch 474 / 524 (indices 47300 to 47399)
# Completed batch 474 / 524
# Processing batch 475 / 524 (indices 47400 to 47499)
# Error translating 'रामराम_ठोकणे': The read operation timed out
# Error translating 'स्पर्शपटल': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 475 / 524
# Processing batch 476 / 524 (indices 47500 to 47599)
# Completed batch 476 / 524
# Processing batch 477 / 524 (indices 47600 to 47699)
# Completed batch 477 / 524
# Processing batch 478 / 524 (indices 47700 to 47799)
# Error translating 'चातुर्य': The read operation timed out
# Completed batch 478 / 524
# Processing batch 479 / 524 (indices 47800 to 47899)
# Error translating 'घरगाडा': the JSON object must be str, bytes or bytearray, not NoneType
# Completed batch 479 / 524
# Processing batch 480 / 524 (indices 47900 to 47999)
# Completed batch 480 / 524
# Processing batch 481 / 524 (indices 48000 to 48099)
# Error translating 'शततंत्री': The read operation timed out
# Completed batch 481 / 524
# Processing batch 482 / 524 (indices 48100 to 48199)
# Completed batch 482 / 524
# Processing batch 483 / 524 (indices 48200 to 48299)
# Completed batch 483 / 524
# Processing batch 484 / 524 (indices 48300 to 48399)
# Completed batch 484 / 524
# Processing batch 485 / 524 (indices 48400 to 48499)
# Error translating 'दिवाळे_निघणे': The read operation timed out
# Error translating 'गुरुदक्षिणा': The read operation timed out
# Completed batch 485 / 524
# Processing batch 486 / 524 (indices 48500 to 48599)
# Completed batch 486 / 524
# Processing batch 487 / 524 (indices 48600 to 48699)
# Completed batch 487 / 524
# Processing batch 488 / 524 (indices 48700 to 48799)
# Completed batch 488 / 524
# Processing batch 489 / 524 (indices 48800 to 48899)
# Error translating 'बालवीर_संघटना': The read operation timed out
# Error translating 'साटोरी': The read operation timed out
# Completed batch 489 / 524
# Processing batch 490 / 524 (indices 48900 to 48999)
# Completed batch 490 / 524
# Processing batch 491 / 524 (indices 49000 to 49099)
# Completed batch 491 / 524
# Processing batch 492 / 524 (indices 49100 to 49199)
# Error translating 'अगत्यपूर्वक': The read operation timed out
# Completed batch 492 / 524
# Processing batch 493 / 524 (indices 49200 to 49299)
# Completed batch 493 / 524
# Processing batch 494 / 524 (indices 49300 to 49399)
# Error translating 'उडवाउडव': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 494 / 524
# Processing batch 495 / 524 (indices 49400 to 49499)
# Completed batch 495 / 524
# Processing batch 496 / 524 (indices 49500 to 49599)
# Error translating 'नल्ल': The read operation timed out
# Completed batch 496 / 524
# Processing batch 497 / 524 (indices 49600 to 49699)
# Completed batch 497 / 524
# Processing batch 498 / 524 (indices 49700 to 49799)
# Error translating 'आत्मा': the JSON object must be str, bytes or bytearray, not NoneType
# Error translating 'पोखरणी': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 498 / 524
# Processing batch 499 / 524 (indices 49800 to 49899)
# Error translating 'तावदान': the JSON object must be str, bytes or bytearray, not NoneType
# Completed batch 499 / 524
# Processing batch 500 / 524 (indices 49900 to 49999)
# Error translating 'दुस्वास': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Error translating 'निस्तरणे': The read operation timed out
# Completed batch 500 / 524
# Processing batch 501 / 524 (indices 50000 to 50099)
# Completed batch 501 / 524
# Processing batch 502 / 524 (indices 50100 to 50199)
# Error translating 'रिंगण': The read operation timed out
# Completed batch 502 / 524
# Processing batch 503 / 524 (indices 50200 to 50299)
# Error translating 'सलज्ज': The read operation timed out
# Completed batch 503 / 524
# Processing batch 504 / 524 (indices 50300 to 50399)
# Error translating 'लोहमार्ग': [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1016)
# Completed batch 504 / 524
# Processing batch 505 / 524 (indices 50400 to 50499)
# Completed batch 505 / 524
# Processing batch 506 / 524 (indices 50500 to 50599)
# Completed batch 506 / 524
# Processing batch 507 / 524 (indices 50600 to 50699)
# Error translating 'सद्गदित': The read operation timed out
# Completed batch 507 / 524
# Processing batch 508 / 524 (indices 50700 to 50799)
# Completed batch 508 / 524
# Processing batch 509 / 524 (indices 50800 to 50899)
# Error translating 'किटकिट': the JSON object must be str, bytes or bytearray, not NoneType
